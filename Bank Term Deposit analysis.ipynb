# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bank_f = pd.read_csv("bank-full.csv")

# %%
bnk = pd.read_csv("bank.csv")

# %%
bnk.describe
# Out:
# <bound method NDFrame.describe of      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]>

# %%
bnk.info
# Out:
# <bound method DataFrame.info of      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]>

# %%
bank_f.info
# Out:
# <bound method DataFrame.info of       age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0      58;"management";"married";"tertiary";"no";2143...
# 1      44;"technician";"single";"secondary";"no";29;"...
# 2      33;"entrepreneur";"married";"secondary";"no";2...
# 3      47;"blue-collar";"married";"unknown";"no";1506...
# 4      33;"unknown";"single";"unknown";"no";1;"no";"n...
# ...                                                  ...
# 45206  51;"technician";"married";"tertiary";"no";825;...
# 45207  71;"retired";"divorced";"primary";"no";1729;"n...
# 45208  72;"retired";"married";"secondary";"no";5715;"...
# 45209  57;"blue-collar";"married";"secondary";"no";66...
# 45210  37;"entrepreneur";"married";"secondary";"no";2...
#
# [45211 rows x 1 columns]>

# %%
bnk
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
bank_deets = pd.read_csv("Book1.csv")

# %%
bank_deets
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_deets.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
bank_deets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
bank_deets["marital"].value_counts()
# Out:
# married     2797
# single      1196
# divorced     528
# Name: marital, dtype: int64

# %%
bnk_upd = pd.read_csv("Bank Deets Updated.csv")

# %%
bnk_upd.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
bnk_upd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
bnk_upd["cons.price.idx"].value_counts()
# Out:
# 93.994    7763
# 93.918    6685
# 92.893    5794
# 93.444    5175
# 94.465    4374
# 93.200    3616
# 93.075    2458
# 92.201     770
# 92.963     715
# 92.431     447
# 92.649     357
# 94.215     311
# 94.199     303
# 92.843     282
# 92.379     267
# 93.369     264
# 94.027     233
# 94.055     229
# 93.876     212
# 94.601     204
# 92.469     178
# 93.749     174
# 92.713     172
# 94.767     128
# 93.798      67
# 92.756      10
# Name: cons.price.idx, dtype: int64

# %%
bnk_upd["y"]
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
#         ...
# 41183    yes
# 41184     no
# 41185     no
# 41186    yes
# 41187     no
# Name: y, Length: 41188, dtype: object

# %% [markdown]
#  Attribute information:
#
#    For more information, read [Moro et al., 2014].
#
#    Input variables:
#    # bank client data:
#    1 - age (numeric)
#    2 - job : type of job (categorical: "admin.","blue-collar","entrepreneur","housemaid","management","retired","self-employed","services","student","technician","unemployed","unknown")
#    3 - marital : marital status (categorical: "divorced","married","single","unknown"; note: "divorced" means divorced or widowed)
#    4 - education (categorical: "basic.4y","basic.6y","basic.9y","high.school","illiterate","professional.course","university.degree","unknown")
#    5 - default: has credit in default? (categorical: "no","yes","unknown")
#    6 - housing: has housing loan? (categorical: "no","yes","unknown")
#    7 - loan: has personal loan? (categorical: "no","yes","unknown")
#    # related with the last contact of the current campaign:
#    8 - contact: contact communication type (categorical: "cellular","telephone")
#    9 - month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#   10 - day_of_week: last contact day of the week (categorical: "mon","tue","wed","thu","fri")
#   11 - duration: last contact duration, in seconds (numeric).
#         Important note:  this attribute highly affects the output target (e.g., if duration=0 then y="no").
#         Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known.
#         Thus, this input should only be included for benchmark purposes and should be discarded if the intention is
#         to have a realistic predictive model.
#    # other attributes:
#   12 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#   13 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
#   14 - previous: number of contacts performed before this campaign and for this client (numeric)
#   15 - poutcome: outcome of the previous marketing campaign (categorical: "failure","nonexistent","success")
#    # social and economic context attributes
#   16 - emp.var.rate: employment variation rate - quarterly indicator (numeric)
#   17 - cons.price.idx: consumer price index - monthly indicator (numeric)
#   18 - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
#   19 - euribor3m: euribor 3 month rate - daily indicator (numeric)
#   20 - nr.employed: number of employees - quarterly indicator (numeric)
#
#   Output variable (desired target):
#   21 - y - has the client subscribed a term deposit? (binary: "yes","no")
#
# 8. Missing Attribute Values: There are several missing values in some categorical attributes, all coded with the "unknown" label. These missing values can be treated as a possible class label or using deletion or imputation techniques.

# %%
sns.scatterplot(data=bank_deets,x="job", y="education", hue="y")
# Out:
# <AxesSubplot:xlabel='job', ylabel='education'>

# %%
sns.boxplot(data=bank_deets, x="age", y="y")
# Out:
# <AxesSubplot:xlabel='age', ylabel='y'>

# %%
bank_deets["housing"].value_counts()
# Out:
# yes    2559
# no     1962
# Name: housing, dtype: int64

# %%
bnk_upd["housing"].value_counts()
# Out:
# yes        21576
# no         18622
# unknown      990
# Name: housing, dtype: int64

# %%
bnk_upd["default"].value_counts()
# Out:
# no         32588
# unknown     8597
# yes            3
# Name: default, dtype: int64

# %%
bnk_upd["loan"].value_counts()
# Out:
# no         33950
# yes         6248
# unknown      990
# Name: loan, dtype: int64

# %%
bnk_upd["job"].value_counts()
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %%
plt.figure(figsize=(10,8), dpi=150)
sns.boxplot(data=bnk_upd, x="job", y="age", hue="y")
plt.xticks(rotation=75);

# %%
plt.figure(figsize=(10,8), dpi=150)
sns.boxplot(data=bnk_upd, x="marital", y="age", hue="y")
plt.xticks(rotation=75);

# %%
sns.countplot(x="y", data=bnk_upd, hue="default")
# Out:
# <AxesSubplot:xlabel='y', ylabel='count'>

# %%
sns.countplot(x="default", data=bnk_upd)
plt.ylim(0,20)
# Out:
# (0.0, 20.0)

# %%
bnk_upd["loan"].value_counts()
# Out:
# no         33950
# yes         6248
# unknown      990
# Name: loan, dtype: int64

# %%
bnk_upd["housing"].value_counts()
# Out:
# yes        21576
# no         18622
# unknown      990
# Name: housing, dtype: int64

# %%
bnk_upd["default"].value_counts()
# Out:
# no         32588
# unknown     8597
# yes            3
# Name: default, dtype: int64

# %%
bnk_upd["marital"].value_counts()
# Out:
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: marital, dtype: int64

# %%
bnk_upd["poutcome"].value_counts()
# Out:
# nonexistent    35563
# failure         4252
# success         1373
# Name: poutcome, dtype: int64

# %%
bnk_upd["y"].value_counts()
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %%
plt.figure(figsize=(8,6), dpi=100)
sns.countplot(x="education", data=bnk_upd)
plt.xticks(rotation=60);

# %%
plt.figure(figsize=(8,6), dpi=100)
sns.countplot(x="job", data=bnk_upd)
plt.xticks(rotation=60);

# %%
plt.figure(figsize=(8,6), dpi=100)
sns.countplot(x="marital", data=bnk_upd)
plt.xticks(rotation=60);

# %%
plt.figure(figsize=(8,6), dpi=100)
sns.countplot(x="contact", data=bnk_upd, hue="y")
plt.xticks(rotation=60);

# %%
plt.figure(figsize=(8,6), dpi=100)
sns.countplot(x="poutcome", data=bnk_upd)
plt.xticks(rotation=60);

# %%
bnk_upd[(bnk_upd["housing"] == "unknown") & (bnk_upd["loan"] == "unknown")]
# Out:
#        age          job   marital            education  default  housing  \
# 29      55      unknown   married    university.degree  unknown  unknown
# 81      51  blue-collar   married             basic.4y  unknown  unknown
# 261     27  blue-collar    single             basic.6y       no  unknown
# 385     59   management   married             basic.4y  unknown  unknown
# 401     48     services   married          high.school  unknown  unknown
# ...    ...          ...       ...                  ...      ...      ...
# 40990   31       admin.    single    university.degree       no  unknown
# 41014   31   technician    single  professional.course       no  unknown
# 41015   34       admin.  divorced    university.degree       no  unknown
# 41029   46   management   married    university.degree       no  unknown
# 41115   42     services  divorced    university.degree       no  unknown
#
#           loan    contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
bnk_upd[bnk_upd["housing"] == "unknown"]
# Out:
#        age          job   marital            education  default  housing  \
# 29      55      unknown   married    university.degree  unknown  unknown
# 81      51  blue-collar   married             basic.4y  unknown  unknown
# 261     27  blue-collar    single             basic.6y       no  unknown
# 385     59   management   married             basic.4y  unknown  unknown
# 401     48     services   married          high.school  unknown  unknown
# ...    ...          ...       ...                  ...      ...      ...
# 40990   31       admin.    single    university.degree       no  unknown
# 41014   31   technician    single  professional.course       no  unknown
# 41015   34       admin.  divorced    university.degree       no  unknown
# 41029   46   management   married    university.degree       no  unknown
# 41115   42     services  divorced    university.degree       no  unknown
#
#           loan    contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
bnk_upd[bnk_upd["loan"] == "unknown"]
# Out:
#        age          job   marital            education  default  housing  \
# 29      55      unknown   married    university.degree  unknown  unknown
# 81      51  blue-collar   married             basic.4y  unknown  unknown
# 261     27  blue-collar    single             basic.6y       no  unknown
# 385     59   management   married             basic.4y  unknown  unknown
# 401     48     services   married          high.school  unknown  unknown
# ...    ...          ...       ...                  ...      ...      ...
# 40990   31       admin.    single    university.degree       no  unknown
# 41014   31   technician    single  professional.course       no  unknown
# 41015   34       admin.  divorced    university.degree       no  unknown
# 41029   46   management   married    university.degree       no  unknown
# 41115   42     services  divorced    university.degree       no  unknown
#
#           loan    contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
bnk_upd[bnk_upd["duration"] == 0]
# Out:
#        age          job   marital          education default housing loan  \
# 6251    39       admin.   married        high.school      no     yes   no
# 23031   59   management   married  university.degree      no     yes   no
# 28063   53  blue-collar  divorced        high.school      no     yes   no
# 33015   31  blue-collar   married           basic.9y      no      no   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 6251   telephone   may         tue  ...         4    999         0
# 23031   cellular   aug         tue  ...        10    999         0
# 28063   cellular   apr         fri  ...         3    999         0
# 33015   cellular   may         mon  ...         2    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 6251   nonexistent          1.1          93.994          -36.4      4.857
# 23031  nonexistent          1.4          93.444          -36.1      4.965
# ...

# %%
bnk_upd["cons.price.idx"].idxmin()
# Out:
# 37117

# %%
bnk_upd.iloc[41060]
# Out:
# age                      46
# job                  admin.
# marital             married
# education          basic.9y
# default                  no
# housing                 yes
# loan                     no
# contact           telephone
# month                   nov
# day_of_week             tue
# duration                 18
# campaign                  1
# pdays                   999
# previous                  1
# poutcome            failure
# emp.var.rate           -1.1
# cons.price.idx       94.767
# cons.conf.idx         -50.8
# euribor3m             1.047
# nr.employed          4963.6
# y                        no
# Name: 41060, dtype: object

# %%
bnk_upd.iloc[37117]
# Out:
# age                        41
# job                    admin.
# marital               married
# education         high.school
# default                    no
# housing                    no
# loan                       no
# contact              cellular
# month                     aug
# day_of_week               tue
# duration                  151
# campaign                    1
# pdays                     999
# previous                    0
# poutcome          nonexistent
# emp.var.rate             -2.9
# cons.price.idx         92.201
# cons.conf.idx           -31.4
# euribor3m               0.884
# nr.employed            5076.2
# y                          no
# Name: 37117, dtype: object

# %%
bnk_upd["campaign"].idxmin()
# Out:
# 0

# %%
bnk_upd.iloc[0]
# Out:
# age                        56
# job                 housemaid
# marital               married
# education            basic.4y
# default                    no
# housing                    no
# loan                       no
# contact             telephone
# month                     may
# day_of_week               mon
# duration                  261
# campaign                    1
# pdays                     999
# previous                    0
# poutcome          nonexistent
# emp.var.rate              1.1
# cons.price.idx         93.994
# cons.conf.idx           -36.4
# euribor3m               4.857
# nr.employed            5191.0
# y                          no
# Name: 0, dtype: object

# %% [markdown]
# Attribute information:
#
#    For more information, read [Moro et al., 2014].
#
#    Input variables:
#    # bank client data:
#    1 - age (numeric)
#    2 - job : type of job (categorical: "admin.","blue-collar","entrepreneur","housemaid","management","retired","self-employed","services","student","technician","unemployed","unknown")
#    3 - marital : marital status (categorical: "divorced","married","single","unknown"; note: "divorced" means divorced or widowed)
#    4 - education (categorical: "basic.4y","basic.6y","basic.9y","high.school","illiterate","professional.course","university.degree","unknown")
#    5 - default: has credit in default? (categorical: "no","yes","unknown")
#    6 - housing: has housing loan? (categorical: "no","yes","unknown")
#    7 - loan: has personal loan? (categorical: "no","yes","unknown")
#    # related with the last contact of the current campaign:
#    8 - contact: contact communication type (categorical: "cellular","telephone")
#    9 - month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#   10 - day_of_week: last contact day of the week (categorical: "mon","tue","wed","thu","fri")
#   11 - duration: last contact duration, in seconds (numeric).
#         Important note:  this attribute highly affects the output target (e.g., if duration=0 then y="no").
#         Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known.
#         Thus, this input should only be included for benchmark purposes and should be discarded if the intention is
#         to have a realistic predictive model.
#    # other attributes:
#   12 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#   13 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
#   14 - previous: number of contacts performed before this campaign and for this client (numeric)
#   15 - poutcome: outcome of the previous marketing campaign (categorical: "failure","nonexistent","success")
#    # social and economic context attributes
#   16 - emp.var.rate: employment variation rate - quarterly indicator (numeric)
#   17 - cons.price.idx: consumer price index - monthly indicator (numeric)
#   18 - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
#   19 - euribor3m: euribor 3 month rate - daily indicator (numeric)
#   20 - nr.employed: number of employees - quarterly indicator (numeric)
#
#   Output variable (desired target):
#   21 - y - has the client subscribed a term deposit? (binary: "yes","no")
#
# 8. Missing Attribute Values: There are several missing values in some categorical attributes, all coded with the "unknown" label. These missing values can be treated as a possible class label or using deletion or imputation techniques.

# %%
bnk_upd.iloc[29]
# Out:
# age                              55
# job                         unknown
# marital                     married
# education         university.degree
# default                     unknown
# housing                     unknown
# loan                        unknown
# contact                   telephone
# month                           may
# day_of_week                     mon
# duration                        362
# campaign                          1
# pdays                           999
# previous                          0
# poutcome                nonexistent
# emp.var.rate                    1.1
# cons.price.idx               93.994
# cons.conf.idx                 -36.4
# euribor3m                     4.857
# nr.employed                  5191.0
# y                                no
# Name: 29, dtype: object

# %%
bnk_upd[bnk_upd["job"] == "unknown"]
# Out:
#        age      job   marital            education  default  housing     loan  \
# 29      55  unknown   married    university.degree  unknown  unknown  unknown
# 35      55  unknown   married             basic.4y  unknown      yes       no
# 73      57  unknown   married              unknown  unknown       no       no
# 91      57  unknown   married              unknown  unknown      yes       no
# 144     38  unknown  divorced          high.school  unknown      yes       no
# ...    ...      ...       ...                  ...      ...      ...      ...
# 40370   59  unknown   married              unknown       no       no       no
# 40428   64  unknown   married              unknown       no      yes       no
# 40656   67  unknown  divorced              unknown  unknown      yes       no
# 41005   63  unknown   married  professional.course       no       no       no
# 41108   64  unknown   married              unknown       no       no       no
#
# ...

# %%
bnk_upd[(bnk_upd["job"].isin(["entrepreneur","self-employed"])) & (bnk_upd["y"] == "yes")]
# Out:
#        age            job   marital            education  default housing  \
# 83      49   entrepreneur   married    university.degree  unknown     yes
# 856     41   entrepreneur   married    university.degree       no     yes
# 1078    44   entrepreneur   married             basic.4y  unknown      no
# 1444    31   entrepreneur  divorced          high.school       no     yes
# 2645    45   entrepreneur   married    university.degree       no     yes
# ...    ...            ...       ...                  ...      ...     ...
# 40517   58  self-employed   married    university.degree       no      no
# 40619   43   entrepreneur   married    university.degree       no      no
# 40738   39   entrepreneur   married  professional.course       no      no
# 40877   22  self-employed    single  professional.course       no     yes
# 40993   50   entrepreneur  divorced    university.degree       no     yes
#
#       loan    contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
bnk_upd["job"].value_counts()
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %%
bnk_upd[(bnk_upd["job"].isin(["entrepreneur","self-employed"])) &~ (bnk_upd["y"] == "yes")]
# Out:
#        age            job  marital          education  default housing loan  \
# 27      39  self-employed  married           basic.9y  unknown      no   no
# 41      32   entrepreneur  married        high.school       no     yes   no
# 60      47   entrepreneur  married  university.degree  unknown      no   no
# 108     42   entrepreneur  married            unknown  unknown     yes   no
# 151     56   entrepreneur  married            unknown  unknown     yes   no
# ...    ...            ...      ...                ...      ...     ...  ...
# 40961   54  self-employed  married  university.degree       no      no   no
# 40963   54  self-employed  married  university.degree       no     yes   no
# 41023   27  self-employed   single  university.degree       no      no   no
# 41133   28  self-employed   single  university.degree       no     yes   no
# 41168   38   entrepreneur  married  university.degree       no      no   no
#
# ...

# %%
1456+1421-2604
# Out:
# 273

# %%
sns.countplot(x="y", data=bnk_upd)
# Out:
# <AxesSubplot:xlabel='y', ylabel='count'>

# %%
bnk_upd.corr()
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000 -0.000866  0.004594 -0.034369  0.024365
# duration       -0.000866  1.000000 -0.071699 -0.047577  0.020640
# campaign        0.004594 -0.071699  1.000000  0.052584 -0.079141
# pdays          -0.034369 -0.047577  0.052584  1.000000 -0.587514
# previous        0.024365  0.020640 -0.079141 -0.587514  1.000000
# emp.var.rate   -0.000371 -0.027968  0.150754  0.271004 -0.420489
# cons.price.idx  0.000857  0.005312  0.127836  0.078889 -0.203130
# cons.conf.idx   0.129372 -0.008173 -0.013733 -0.091342 -0.050936
# euribor3m       0.010767 -0.032897  0.135133  0.296899 -0.454494
# nr.employed    -0.017725 -0.044703  0.144095  0.372605 -0.501333
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.000371        0.000857       0.129372   0.010767
# duration           -0.027968        0.005312      -0.008173  -0.032897
# ...
